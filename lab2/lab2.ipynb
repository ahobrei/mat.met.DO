# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Завантаження даних з файлу
data = np.loadtxt('data.txt', delimiter='\t', dtype=int)
# Перевірка завантажених даних
print("Дані розмірність:\n", data.shape)
# Колонка для Ore
#ore_test = data[:, 0]  
#print(f"Перший елемент {ore_test}")
# Out:
# Дані розмірність:
#  (122, 3)

# %%
price_ectoplasm = 56  # Ціна Ектоплазми
price_ore = 0.2
price_wood = 0.66
price_t6 = 0.66
price = np.array([price_ectoplasm, price_ore, price_wood])

# %%
r = (data * price).sum(axis=1)/666
print(f"Вартість одного Ітема при експерименті розщеплення {r}")
# Out:
# Вартість одного Ітема при експерименті розщеплення [17.52837838 19.79183183 19.4466967  19.10705706 20.29693694 19.53399399
#  18.61612613 19.96171171 20.96708709 19.04012012 18.61111111 19.10597598
#  18.70132132 19.27123123 17.86036036 19.96204204 19.97015015 18.9663964
#  20.77711712 19.05582583 19.2866967  17.85711712 20.12366366 18.88792793
#  18.77624625 19.54192192 19.62783784 20.63309309 17.87225225 18.50291291
#  18.43630631 19.29672673 18.01705706 19.00654655 19.35792793 19.78765766
#  19.6924024  20.79777778 17.10384384 17.69465465 18.53471471 19.20921922
#  17.42339339 20.4603003  20.57       17.60312312 18.53597598 17.2512012
#  16.19129129 20.70930931 19.186997   18.44972973 18.54219219 19.63528529
#  16.3554955  19.28474474 20.22417417 18.9639039  19.45204204 19.77054054
#  18.35951952 14.16417417 19.52945946 19.35084084 19.4442042  17.11357357
#  20.31234234 17.11477477 19.95123123 18.63840841 18.94234234 19.6136036
#  18.0478979  18.68951952 19.54615616 18.88456456 18.96147147 15.68117117
#  17.34345345 19.29657658 16.3333033  18.79141141 17.86405405 19.54216216
#  19.70174174 18.61018018 17.50753754 20.48690691 18.78231231 18.93147147
#  20.80891892 18.36363363 17.03162162 18.53042042 17.49852853 18.26510511
#  18.92684685 19.70531532 18.69003003 19.52966967 17.34783784 20.39426426
#  19.38540541 18.12399399 20.28552553 20.27801802 19.44279279 19.52753754
#  19.04273273 19.10039039 17.35924925 19.35501502 20.28657658 19.42468468
#  19.11483483 19.94813814 20.46144144 17.43696697 20.37093093 18.77765766
#  16.60591592 19.27720721]

# %%
# Задаємо ціни базових предметів
prices_base = np.array([price_t6, price_ore, price_wood])  # Ціни: [T6, руда, дерево]

cost_disassembly = 0.0666  # Вартість розщеплення

# Кількість базових предметів, необхідних для створення одного предмета
resources_required = np.array([11, 11, 11])

price_of_crafting = sum(prices_base * resources_required)

print(f"Вартість одного предмету {price_of_crafting}")
# Out:
# Вартість одного предмету 16.720000000000002

# %%
# Знаходимо мін та макс для гістограми
# Робимо крок гістограми 0.5
bins = np.arange(np.floor(r.min()), np.ceil(r.max() + 3), 0.66)
bins[0:]
# Out:
# array([14.  , 14.66, 15.32, 15.98, 16.64, 17.3 , 17.96, 18.62, 19.28,
#        19.94, 20.6 , 21.26, 21.92, 22.58, 23.24, 23.9 ])

# %%
plt.figure(figsize=(9, 1))

plt.hist(r, bins=bins, color='skyblue', edgecolor='black', alpha=0.2, label="Розподіл ціни")

plt.xlabel('Значення')
plt.ylabel('Частота')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.2)
plt.show()

# %%
r_sorted = np.array(sorted(r))
print(r_sorted)

plt.figure(figsize=(6, 6))


plt.plot(r_sorted, color='blue')
plt.plot(np.repeat(price_of_crafting, 122), color='red')
plt.ylabel("Вартість")
plt.xlabel("Номер Експерименту")
plt.grid()
plt.show()
# Out:
# [14.16417417 15.68117117 16.19129129 16.3333033  16.3554955  16.60591592
#  17.03162162 17.10384384 17.11357357 17.11477477 17.2512012  17.34345345
#  17.34783784 17.35924925 17.42339339 17.43696697 17.49852853 17.50753754
#  17.52837838 17.60312312 17.69465465 17.85711712 17.86036036 17.86405405
#  17.87225225 18.01705706 18.0478979  18.12399399 18.26510511 18.35951952
#  18.36363363 18.43630631 18.44972973 18.50291291 18.53042042 18.53471471
#  18.53597598 18.54219219 18.61018018 18.61111111 18.61612613 18.63840841
#  18.68951952 18.69003003 18.70132132 18.77624625 18.77765766 18.78231231
#  18.79141141 18.88456456 18.88792793 18.92684685 18.93147147 18.94234234
#  18.96147147 18.9639039  18.9663964  19.00654655 19.04012012 19.04273273
#  19.05582583 19.10039039 19.10597598 19.10705706 19.11483483 19.186997
#  19.20921922 19.27123123 19.27720721 19.28474474 19.2866967  19.29657658
#  19.29672673 19.35084084 19.35501502 19.35792793 19.38540541 19.42468468
#  19.44279279 19.4442042  19.4466967  19.45204204 19.52753754 19.52945946
#  19.52966967 19.53399399 19.54192192 19.54216216 19.54615616 19.6136036
#  19.62783784 19.63528529 19.6924024  19.70174174 19.70531532 19.77054054
#  19.78765766 19.79183183 19.94813814 19.95123123 19.96171171 19.96204204
#  19.97015015 20.12366366 20.22417417 20.27801802 20.28552553 20.28657658
#  20.29693694 20.31234234 20.37093093 20.39426426 20.4603003  20.46144144
#  20.48690691 20.57       20.63309309 20.70930931 20.77711712 20.79777778
#  20.80891892 20.96708709]

# %%
profit_crafting = r_sorted - price_of_crafting
print(f"Прибуток як різниця між вартість та отриманим результатом {profit_crafting.sum()/89}")
# Out:
# Прибуток як різниця між вартість та отриманим результатом 3.0069578567331345

# %%
# Завантаження даних про результати розщеплення
ectoplasm, ore, wood = data[:, 0], data[:, 1], data[:, 2]

# Розрахунок середньої кількості отриманих предметів
avg_ectoplasm = np.mean(ectoplasm)
avg_ore = np.mean(ore)
avg_wood = np.mean(wood)

# Розрахунок середньої виручки
avg_revenue = avg_ectoplasm * price_ectoplasm + avg_ore * prices_base[1] + avg_wood * prices_base[2]

# Розрахунок собівартості
cost_per_item = np.sum(resources_required * prices_base) + cost_disassembly

# Розрахунок прибутку
profit = avg_revenue - cost_per_item

# Виведення результатів
print(f"Середня кількість Ектоплами: {avg_ectoplasm:.2f}")
print(f"Середня кількість руди: {avg_ore:.2f}")
print(f"Середня кількість дерева: {avg_wood:.2f}")
print(f"Собівартість створення одного предмета: {cost_per_item:.2f} монет")
print(f"Середній прибуток: {profit:.2f} монет на одну операцію")

# Візуалізація залежності прибутку від ціни базових предметів
prices_variation = np.linspace(2, 6, 9)  # Варіюємо ціну базових предметів
profits = []

for price in prices_variation:
    temp_prices = np.array([price, price, price])
    temp_cost = np.sum(resources_required * temp_prices) + cost_disassembly
    temp_profit = avg_revenue - temp_cost
    profits.append(temp_profit)

plt.figure(figsize=(2, 6))
plt.plot(prices_variation, profits, label="Прибуток")
plt.axhline(0, color='red', linestyle='--', label="Точка беззбитковості")
plt.xlabel("Ціна базових предметів (однакова для всіх)")
plt.ylabel("Прибуток")
plt.title("Залежність прибутку від ціни базових предметів")
plt.legend()
plt.grid()
plt.show()
# Out:
# Середня кількість Ектоплами: 221.57
# Середня кількість руди: 222.64
# Середня кількість дерева: 217.88
# Собівартість створення одного предмета: 16.79 монет
# Середній прибуток: 12579.67 монет на одну операцію

# %% [markdown]
# ## 1_linear_programming.ipynb

# %%
# %pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /workspaces/mat.met.DO/.venv/lib/python3.12/site-packages (from scipy) (2.2.4)
# Downloading scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 74.2 MB/s eta 0:00:00:00:01
# Installing collected packages: scipy
# Successfully installed scipy-1.15.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import linprog

# %%
B = 100 # золотих

x1 = np.arange(0, 15)
x2 = np.arange(0, 26)
x1, x2 = np.meshgrid(x1, x2)
x3 = (B - 9*x1 - 7*x2)/12

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(x1, x2, x3, alpha=0.5)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('x3')
plt.title("Площина обмежень")
# Out:
# Text(0.5, 0.92, 'Площина обмежень')

# %%
x1 = np.linspace(0, 77, 180)
x21 = (B-2*x1)/7 # За умови що х3=0
x31 = (B-7*x1)/32 # За умови що х2=0

plt.fill_between(x1, x21, 0, where=x21<0, alpha=0.2, color='red')
plt.fill_between(x1, x31, 0, where=x31<0, alpha=0.2, color='blue')

# %%
# обертаємо задачу на знаходження мінімуму
c = np.array([8, 7, 8])

# Записуємо матрицю умов (з коефіцієнтів рівнянь)
A = np.array([
    [2, 7, 77]
])

# Записуємо матрицю розвязків
b = np.array([B])

# Записуємо вектор обмежень області значень
bnd = [(0, None), (0, None), (0, None)]

# Знаходимо розвязки задачі
res = linprog(-c, A_ub=A, b_ub=b, bounds=bnd)

x1, x2, x3 = res.x
profit = -res.fun

# Результати
print(f"Кількість предмету 1: {x1}")
print(f"Кількість предмету 2: {x2}")
print(f"Кількість предмету 3: {x3}")
print(f"Загальний прибуток: {profit} золотих")
# Out:
# Кількість предмету 1: 50.0
# Кількість предмету 2: 0.0
# Кількість предмету 3: 0.0
# Загальний прибуток: 400.0 золотих

# %% [markdown]
# ## Створення моделей

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
db = load_diabetes()
X = np.array(db.data)
y = np.array(db.target)
print(f"Data shape: X={X.shape} y={y.shape}")
X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# Data shape: X=(442, 10) y=(442,)

# %%
# Set the model parameters.
n_estimators = 123
max_depth = 2
max_features = 3
  
# Create and train model.
rf = RandomForestRegressor(n_estimators = n_estimators, max_depth = max_depth, max_features = max_features)
rf.fit(X_train, y_train)
  
# Use the model to make predictions on the test dataset.
predictions = rf.predict(X_test)

# %%
# Оцінюємо точність
mse = mean_squared_error(y_test, predictions)
print(f"Середньоквадратична помилка (MSE): {mse:.4f}")
# Out:
# Середньоквадратична помилка (MSE): 3736.4575

# %%
X_grid = np.linspace(np.min(X), np.max(X), 1000).reshape(100, 10)
y_grid_pred = rf.predict(X_grid)

# %%
# Візуалізація
f = 0
plt.scatter(X_train[:, f], y_train, label=f"Навчальні дані {f}", color="blue", alpha=0.6)
plt.scatter(X_test[:, f], y_test, label=f"Тестові дані {f}", color="red", alpha=0.6)
plt.plot(X_grid[:, f], y_grid_pred, label=f"Прогноз RandomForest {f}", color="green")
plt.legend()
plt.xlabel("X")
plt.ylabel("y")
plt.title("Регресія з RandomForestRegressor")
plt.show()
